# %%
import requests
import random
from bs4 import BeautifulSoup
import pandas as pd
import json
import concurrent.futures

# %% [markdown]
# # TrustPilot

# %%
class TrustPilotScraper:
    """
    A class for scraping reviews from Trustpilot and transforming them into a dataframe.
    """

    def __init__(self, url, num_pages):
        """
        Initialize the TrustPilotScraper object with the Trustpilot URL and number of pages to scrape.

        Args:
            url (str): The URL of the Trustpilot page to scrape.
            num_pages (int): The number of pages to scrape.
        """
        self.url = url
        self.url_company = url.split("/")[-1].split(".")[0]
        self.num_pages = num_pages

    def scrape_reviews(self):
        """
        Scrape reviews from the Trustpilot URL for the specified number of pages.

        Returns:
            tuple: A tuple containing lists of reviews, headlines, ratings, and authors.
        """
        base_url = self.url + '?page='
        urls = [base_url + str(i) for i in range(1, self.num_pages + 1)]

        with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
            results = executor.map(self.__scrape_trustpilot_data, urls)

        page_results = list(results)

        reviews, headlines, ratings, authors, dates = [], [], [], [], []
        for page_result in page_results:
            page_reviews, page_headlines, page_ratings, page_authors, page_dates = self.__extract_nested_content(page_result)
            reviews.extend(page_reviews)
            headlines.extend(page_headlines)
            ratings.extend(page_ratings)
            authors.extend(page_authors)
            dates.extend(page_dates)
        self.page_results = page_result

        return reviews, headlines, ratings, authors, dates

    def __scrape_trustpilot_data(self, url):
        """
        Private method to scrape data from a given Trustpilot URL.

        Args:
            url (str): The URL to scrape.

        Returns:
            dict: The scraped JSON data.
        """
        try:
            response = requests.get(url)
            response.raise_for_status()
        except requests.exceptions.RequestException as e:
            print(f"Error scraping URL: {url}\n{str(e)}")
            return None

        try:
            soup = BeautifulSoup(response.text, 'html.parser')
            script_tag = soup.find('script', {'data-business-unit-json-ld': 'true'})
            json_str = script_tag.text.strip()
            json_data = json.loads(json_str)
            return json_data
        except (AttributeError, ValueError, KeyError) as e:
            print(f"Error parsing JSON data for URL: {url}\n{str(e)}")
            return None

    def __get_content_from_page_results(self, page_result, key):
        """
        Private method to extract nested content from the scraped JSON data.

        Args:
            page_result (dict): The scraped JSON data for a single page.
            key (str): The key to extract from the JSON data.

        Returns:
            list: A list of extracted content.
        """
        if page_result and '@graph' in page_result:
            page_content = [i[key] for i in page_result['@graph'] if i.get('@type') == 'Review']
            return page_content
        return []

    def __extract_nested_content(self, page_result):
        """
        Private method to extract nested content from a list of scraped JSON data.

        Args:
            page_results (list): A list of scraped JSON data for multiple pages.

        Returns:
            tuple: A tuple containing lists of nested reviews, headlines, ratings, and authors.
        """
        reviews = self.__get_content_from_page_results(page_result, 'reviewBody')
        headlines = self.__get_content_from_page_results(page_result, 'headline')
        ratings = self.__get_content_from_page_results(page_result, 'reviewRating')
        authors = self.__get_content_from_page_results(page_result, 'author')
        dates = self.__get_content_from_page_results(page_result, 'datePublished')
        return reviews, headlines, ratings, authors, dates

    def get_dataframe_results(self, reviews, headlines, ratings, authors, dates):
        """
        Generate a dataframe from the scraped review data.

        Args:
            reviews (list): List of review content.
            headlines (list): List of review headlines.
            ratings (list): List of review ratings.
            authors (list): List of review authors.

        Returns:
            pandas.DataFrame: The dataframe containing the review data.
        """
        df = pd.DataFrame({'review': reviews, 
                           'author': authors, 
                           'headline': headlines, 
                           'ratings': ratings,
                           'date':dates})
        df['company'] = self.url_company
        df_author = self.transform_nested_dataframe_column(df, 'author', ['name', 'url'])
        df_rating = self.transform_nested_dataframe_column(df, 'ratings', ['ratingValue'])
        df['company'] = self.url_company
        return pd.concat([df[['company','date','headline', 'review']], df_author, df_rating], axis=1)


    @staticmethod
    def transform_nested_dataframe_column(df, nested_col, new_cols):
        """
        Transform a nested column in the dataframe into separate columns.

        Args:
            df (pandas.DataFrame): The input dataframe.
            nested_col (str): The name of the nested column to transform.
            new_cols (list): The names of the new columns to create.

        Returns:
            pandas.DataFrame: The transformed dataframe with the new columns.
        """
        df_flat = df[nested_col].apply(pd.Series)[new_cols]
        return df_flat


    def run(self):
        """
        Run the TrustPilotScraper to scrape reviews and generate the dataframe.

        Returns:
            pandas.DataFrame: The dataframe containing the scraped review data.
        """
        reviews, headlines, ratings, authors, dates = self.scrape_reviews()
        df = self.get_dataframe_results(reviews, headlines, ratings, authors,dates)
        return df

# %%
tp = TrustPilotScraper('https://uk.trustpilot.com/review/gymshark.com',5)

# %%
df = tp.run()

# %%
tp.page_results
# Out:
# {'@context': 'https://schema.org',
#  '@graph': [{'@type': 'Organization',
#    '@id': 'https://www.trustpilot.com/#/schema/Organization/1',
#    'name': 'Trustpilot',
#    'legalName': 'Trustpilot A/S',
#    'url': 'https://www.trustpilot.com',
#    'description': 'Read reviews. Write reviews. Find companies.',
#    'sameAs': ['https://en.wikipedia.org/wiki/Trustpilot',
#     'https://www.facebook.com/Trustpilot/',
#     'https://www.instagram.com/trustpilot/',
#     'https://www.linkedin.com/company/trustpilot',
#     'https://twitter.com/Trustpilot',
#     'https://www.youtube.com/c/trustpilotreviews'],
#    'logo': {'@id': 'https://www.trustpilot.com/#/schema/ImageObject/Logo/1'},
#    'email': 'support@trustpilot.com',
#    'address': {'@type': 'PostalAddress',
#     '@id': 'https://www.trustpilot.com/#/schema/PostalAddress/DK',
#     'streetAddress': 'Pilestræde 58, 5th floor',
#     'addressLocality': 'Copenhagen',
#     'addressCountry': 'DK',
#     'postalCode': '1112 København'}},
#   {'@type': 'ImageObject',
#    '@id': 'https://www.trustpilot.com/#/schema/ImageObject/Logo/1',
#    'url': 'https://cdn.trustpilot.net/brand-assets/1.5.0/favicons/android-chrome-512x512.png',
#    'contentUrl': 'https://cdn.trustpilot.net/brand-assets/1.5.0/favicons/android-chrome-512x512.png',
#    'width': {'@type': 'QuantitativeValue',
#     'value': 512,
#     'unitCode': 'E37',
#     'unitText': 'pixel'},
#    'height': {'@type': 'QuantitativeValue',
#     'value': 512,
#     'unitCode': 'E37',
#     'unitText': 'pixel'},
#    'caption': 'Trustpilot Logo',
#    'name': 'Trustpilot'},
#   {'@type': 'WebSite',
#    '@id': 'https://uk.trustpilot.com/#/schema/WebSite/1',
#    'url': 'https://uk.trustpilot.com/',
#    'name': 'Trustpilot (en-GB)',
#    'description': "We're all about consumer reviews. Get the real inside story from shoppers like you. Read, write and share reviews on Trustpilot today.",
#    'publisher': {'@id': 'https://www.trustpilot.com/#/schema/Organization/1'},
#    'copyrightHolder': {'@id': 'https://www.trustpilot.com/#/schema/Organization/1'},
#    'potentialAction': [{'@type': 'SearchAction',
#      'target': {'@type': 'EntryPoint',
#       'urlTemplate': 'https://uk.trustpilot.com/search?query={search_term_string}'},
#      'query-input': 'required name=search_term_string'}],
#    'inLanguage': 'en-GB'},
#   {'@type': 'WebPage',
#    '@id': 'https://uk.trustpilot.com/review/gymshark.com?page=5',
#    'url': 'https://uk.trustpilot.com/review/gymshark.com?page=5',
#    'name': 'Gymshark Reviews',
#    'description': '29,456 people have already reviewed Gymshark. Read about their experiences and share your own! | Read 81-100 Reviews out of 25,295',
#    'isPartOf': {'@id': 'https://uk.trustpilot.com/#/schema/WebSite/1'},
#    'inLanguage': 'en-GB',
#    'breadcrumb': {'@id': 'https://uk.trustpilot.com/review/gymshark.com?page=5/#/schema/BreadcrumbList/1'},
#    'about': {'@id': 'https://www.trustpilot.com/#/schema/Organization/gymshark.com'},
#    'mainEntity': {'@id': 'https://www.trustpilot.com/#/schema/Organization/gymshark.com'},
#    'primaryImageOfPage': {'@id': 'https://www.trustpilot.com/#/schema/ImageObject/gymshark.com'},
#    'hasPart': {'@id': 'https://www.trustpilot.com/#/schema/DataSet/gymshark.com/1'}},
#   {'@type': 'BreadcrumbList',
#    '@id': 'https://uk.trustpilot.com/review/gymshark.com?page=5/#/schema/BreadcrumbList/1',
#    'itemListElement': [{'@type': 'ListItem',
#      'position': 1,
#      'name': 'Home',
#      'item': 'https://uk.trustpilot.com/',
#      'sameAs': 'https://uk.trustpilot.com/'},
#     {'@type': 'ListItem',
#      'position': 2,
#      'name': 'Shopping & Fashion',
#      'item': 'https://uk.trustpilot.com/categories/shopping_fashion',
#      'sameAs': 'https://uk.trustpilot.com/categories/shopping_fashion'},
#     {'@type': 'ListItem',
#      'position': 3,
#      'name': 'Clothing & Underwear',
#      'item': 'https://uk.trustpilot.com/categories/clothing_underwear',
#      'sameAs': 'https://uk.trustpilot.com/categories/clothing_underwear'},
#     {'@type': 'ListItem',
#      'position': 4,
#      'name': 'Activewear shop',
#      'item': 'https://uk.trustpilot.com/categories/activewear_store',
#      'sameAs': 'https://uk.trustpilot.com/categories/activewear_store'},
#     {'@type': 'ListItem',
#      'position': 5,
#      'name': 'Gymshark Reviews',
#      'item': {'@id': 'https://uk.trustpilot.com/review/gymshark.com?page=5'}}]},
#   {'@type': 'ImageObject',
#    '@id': 'https://www.trustpilot.com/#/schema/ImageObject/gymshark.com',
#    'url': 'https://s3-eu-west-1.amazonaws.com/tpd/logos/51083b8c0000640005219165/0x0.png',
#    'contentUrl': 'https://s3-eu-west-1.amazonaws.com/tpd/logos/51083b8c0000640005219165/0x0.png'},
#   {'@type': 'LocalBusiness',
#    '@id': 'https://www.trustpilot.com/#/schema/Organization/gymshark.com',
#    'url': 'https://uk.trustpilot.com/review/gymshark.com',
#    'sameAs': 'http://gymshark.com',
#    'name': 'Gymshark',
#    'description': 'We’re Gymshark. We exist to unite the conditioning* community.  It’s not our goals that unite us, but the things we do to achieve them. Because although our training grounds and end goals might be different, sweat is our sport. And we’re a team of individuals who know that to go further, we go together.  *Conditioning is everything we do today to prepare for tomorrow.',
#    'email': 'support@gymshark.com',
#    'address': {'@type': 'PostalAddress',
#     'streetAddress': 'GSHQ, Central Boulevard',
#     'addressLocality': 'Solihull',
#     'addressCountry': 'GB',
#     'postalCode': 'B90 8AB'},
#    'image': {'@id': 'https://www.trustpilot.com/#/schema/ImageObject/gymshark.com'},
#    'aggregateRating': {'@type': 'AggregateRating',
#     'bestRating': '5',
#     'worstRating': '1',
#     'ratingValue': '3.7',
#     'reviewCount': '29456'},
#    'review': [{'@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64c68f0bd29542c8095f110e'},
#     {'@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64ca9cc9c4234462868e7e8e'},
#     {'@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64d13217c4234462868f66dd'},
#     {'@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64d09cb2706f837cb117234f'},
#     {'@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64c985eac4234462868e5636'},
#     {'@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64d216d56d0f079c833f42b9'},
#     {'@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64d7edb46b024304213441f8'},
#     {'@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64d662e66b02430421340d33'},
#     {'@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64d123f6c4234462868f6389'},
#     {'@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64be9cab706f837cb1149b5b'},
#     {'@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64d0185855846cae13e2264a'},
#     {'@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64c4b3ab706f837cb1157928'},
#     {'@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64c14156706f837cb114fc13'},
#     {'@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64d668708939eed74a3a7e7e'},
#     {'@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64ce15e2706f837cb116d650'},
#     {'@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64c14279706f837cb114fc47'},
#     {'@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64c149e2706f837cb114fdcc'},
#     {'@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64c61cf3c4234462868dcc3a'},
#     {'@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64bd7deb43a7bae0092a5031'},
#     {'@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64d1145f706f837cb1173572'}]},
#   {'@type': 'Review',
#    '@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64c68f0bd29542c8095f110e',
#    'itemReviewed': {'@id': 'https://www.trustpilot.com/#/schema/Organization/gymshark.com'},
#    'author': {'@type': 'Person',
#     'name': 'Moofuly',
#     'url': 'https://uk.trustpilot.com/users/64c68f04c3724000123b2fc1/'},
#    'datePublished': '2023-07-30T18:25:47.000Z',
#    'headline': 'Used to be a great company :(',
#    'reviewBody': 'Customer service has been good enough to still justify making purchases at the company despite the decline in quality. Unfortunately that has become mediocre as well.I made a claim for missing items valued at about 75€ a day after receiving two separate packages both missing one item. The ticket gets processed and the customer service team can’t find the correct information despite providing everything (order number, name, adress etc) fine no problem this kind of stuff happens.This morning I open my inbox to yet again circle back with the company and help them locate my missing items.The newest message from Gymshark states that since it has now been 7 days since I picked up the package they are no longer able to keep processing my claim. Since my issue was not solved in this 7 day time period, their solution was to point me towards their vague new guidelines. Now I’m down 75 euros due to their negligence, this is a great way to make money.  Quality in product has been declining for months but these new “solutions” are shameful & probably not completely legal? I genuinely wouldn’t be surprised to see the company fizzle out completely in the coming years. Which is sad considering their initial products and service were so good. ——Update!——Well they “don’t normally do this” but they decided to give me some kind of good grace refund. Again… my claim was submitted on time, no grace needed? #gaslighting Anyways, I’m happy to say I found a nice new (genuinely) affordable activewear company. I sent back the remaining items from both (large) orders and hope to see a refund for those items soon. After nearly 5 years I’m done shopping at Gymshark.',
#    'reviewRating': {'@type': 'Rating',
#     'bestRating': '5',
#     'worstRating': '1',
#     'ratingValue': '1'},
#    'publisher': {'@id': 'https://www.trustpilot.com/#/schema/Organization/1'},
#    'inLanguage': 'en'},
#   {'@type': 'Review',
#    '@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64ca9cc9c4234462868e7e8e',
#    'itemReviewed': {'@id': 'https://www.trustpilot.com/#/schema/Organization/gymshark.com'},
#    'author': {'@type': 'Person',
#     'name': 'Mrs S Vint',
#     'url': 'https://uk.trustpilot.com/users/5acce7e34de5666d3460edc1/'},
#    'datePublished': '2023-08-02T20:13:29.000Z',
#    'headline': 'Great service couldn’t believe how…',
#    'reviewBody': 'Great service couldn’t believe how quick the order came and the items were fantastic',
#    'reviewRating': {'@type': 'Rating',
#     'bestRating': '5',
#     'worstRating': '1',
#     'ratingValue': '5'},
#    'publisher': {'@id': 'https://www.trustpilot.com/#/schema/Organization/1'},
#    'inLanguage': 'en'},
#   {'@type': 'Review',
#    '@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64d13217c4234462868f66dd',
#    'itemReviewed': {'@id': 'https://www.trustpilot.com/#/schema/Organization/gymshark.com'},
#    'author': {'@type': 'Person',
#     'name': 'Melanie Muir',
#     'url': 'https://uk.trustpilot.com/users/5c82891660266c1d70f3c6df/'},
#    'datePublished': '2023-08-07T20:04:07.000Z',
#    'headline': 'Good all round',
#    'reviewBody': 'Ordering was easy and prompt delivery and goods was true to description',
#    'reviewRating': {'@type': 'Rating',
#     'bestRating': '5',
#     'worstRating': '1',
#     'ratingValue': '5'},
#    'publisher': {'@id': 'https://www.trustpilot.com/#/schema/Organization/1'},
#    'inLanguage': 'en'},
#   {'@type': 'Review',
#    '@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64d09cb2706f837cb117234f',
#    'itemReviewed': {'@id': 'https://www.trustpilot.com/#/schema/Organization/gymshark.com'},
#    'author': {'@type': 'Person',
#     'name': 'Pistol Pete',
#     'url': 'https://uk.trustpilot.com/users/64d09cb1904a9a001272e46e/'},
#    'datePublished': '2023-08-07T09:26:42.000Z',
#    'headline': 'Great Customers service.',
#    'reviewBody': 'The customer service I got when I found the product damaged on delivery was excellent!',
#    'reviewRating': {'@type': 'Rating',
#     'bestRating': '5',
#     'worstRating': '1',
#     'ratingValue': '5'},
#    'publisher': {'@id': 'https://www.trustpilot.com/#/schema/Organization/1'},
#    'inLanguage': 'en'},
#   {'@type': 'Review',
#    '@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64c985eac4234462868e5636',
#    'itemReviewed': {'@id': 'https://www.trustpilot.com/#/schema/Organization/gymshark.com'},
#    'author': {'@type': 'Person',
#     'name': 'SARAHGOLDER',
#     'url': 'https://uk.trustpilot.com/users/62c5fd5ce00f1600153f36f3/'},
#    'datePublished': '2023-08-02T00:23:38.000Z',
#    'headline': 'Shorts & T shirts',
#    'reviewBody': 'Look nice, wash nice , nice material good size , my 16 yr old loves them all  shorts & T-shirts',
#    'reviewRating': {'@type': 'Rating',
#     'bestRating': '5',
#     'worstRating': '1',
#     'ratingValue': '5'},
#    'publisher': {'@id': 'https://www.trustpilot.com/#/schema/Organization/1'},
#    'inLanguage': 'en'},
#   {'@type': 'Review',
#    '@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64d216d56d0f079c833f42b9',
#    'itemReviewed': {'@id': 'https://www.trustpilot.com/#/schema/Organization/gymshark.com'},
#    'author': {'@type': 'Person',
#     'name': 'Patryk',
#     'url': 'https://uk.trustpilot.com/users/53657cad00006400017181e2/'},
#    'datePublished': '2023-08-08T12:20:05.000Z',
#    'headline': 'Good service',
#    'reviewBody': 'Easy website to navigate. Quick delivery, products match descriptions on the website',
#    'reviewRating': {'@type': 'Rating',
#     'bestRating': '5',
#     'worstRating': '1',
#     'ratingValue': '5'},
#    'publisher': {'@id': 'https://www.trustpilot.com/#/schema/Organization/1'},
#    'inLanguage': 'en'},
#   {'@type': 'Review',
#    '@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64d7edb46b024304213441f8',
#    'itemReviewed': {'@id': 'https://www.trustpilot.com/#/schema/Organization/gymshark.com'},
#    'author': {'@type': 'Person',
#     'name': 'Charley Gadd',
#     'url': 'https://uk.trustpilot.com/users/64d7edb3c647900012de1a1b/'},
#    'datePublished': '2023-08-12T22:38:12.000Z',
#    'headline': 'Fast delivery and good quality',
#    'reviewBody': 'Fast delivery. Good quality clothing and not expensive',
#    'reviewRating': {'@type': 'Rating',
#     'bestRating': '5',
#     'worstRating': '1',
#     'ratingValue': '5'},
#    'publisher': {'@id': 'https://www.trustpilot.com/#/schema/Organization/1'},
#    'inLanguage': 'en'},
#   {'@type': 'Review',
#    '@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64d662e66b02430421340d33',
#    'itemReviewed': {'@id': 'https://www.trustpilot.com/#/schema/Organization/gymshark.com'},
#    'author': {'@type': 'Person',
#     'name': 'Annmarie   Baker',
#     'url': 'https://uk.trustpilot.com/users/5feb5884dfffd500199458c9/'},
#    'datePublished': '2023-08-11T18:33:42.000Z',
#    'headline': 'Very fast delivery and great product',
#    'reviewBody': 'Very fast delivery and great product',
#    'reviewRating': {'@type': 'Rating',
#     'bestRating': '5',
#     'worstRating': '1',
#     'ratingValue': '5'},
#    'publisher': {'@id': 'https://www.trustpilot.com/#/schema/Organization/1'},
#    'inLanguage': 'en'},
#   {'@type': 'Review',
#    '@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64d123f6c4234462868f6389',
#    'itemReviewed': {'@id': 'https://www.trustpilot.com/#/schema/Organization/gymshark.com'},
#    'author': {'@type': 'Person',
#     'name': 'Luke',
#     'url': 'https://uk.trustpilot.com/users/5bb35d4a4de5666d340720ad/'},
#    'datePublished': '2023-08-07T19:03:50.000Z',
#    'headline': 'Ordered on a Sunday with standard…',
#    'reviewBody': 'Ordered on a Sunday with standard delivery and it showed up on Monday. Both items were great.',
#    'reviewRating': {'@type': 'Rating',
#     'bestRating': '5',
#     'worstRating': '1',
#     'ratingValue': '5'},
#    'publisher': {'@id': 'https://www.trustpilot.com/#/schema/Organization/1'},
#    'inLanguage': 'en'},
#   {'@type': 'Review',
#    '@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64be9cab706f837cb1149b5b',
#    'itemReviewed': {'@id': 'https://www.trustpilot.com/#/schema/Organization/gymshark.com'},
#    'author': {'@type': 'Person',
#     'name': 'Beth Stanworth',
#     'url': 'https://uk.trustpilot.com/users/63c58b99d4c8220012158bfd/'},
#    'datePublished': '2023-07-24T17:45:47.000Z',
#    'headline': 'Exceptional quality',
#    'reviewBody': 'I’ve become obsessed with Gymshark. Everything I’ve bought has fit perfectly and the quality is exceptional. 100% my favourite sports brand.',
#    'reviewRating': {'@type': 'Rating',
#     'bestRating': '5',
#     'worstRating': '1',
#     'ratingValue': '5'},
#    'publisher': {'@id': 'https://www.trustpilot.com/#/schema/Organization/1'},
#    'inLanguage': 'en'},
#   {'@type': 'Review',
#    '@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64d0185855846cae13e2264a',
#    'itemReviewed': {'@id': 'https://www.trustpilot.com/#/schema/Organization/gymshark.com'},
#    'author': {'@type': 'Person',
#     'name': 'R J',
#     'url': 'https://uk.trustpilot.com/users/64d017f6546e730012370651/'},
#    'datePublished': '2023-08-07T00:02:00.000Z',
#    'headline': 'Fast delivery and quality is spot on as…',
#    'reviewBody': 'Fast delivery and quality is spot on as usual',
#    'reviewRating': {'@type': 'Rating',
#     'bestRating': '5',
#     'worstRating': '1',
#     'ratingValue': '5'},
#    'publisher': {'@id': 'https://www.trustpilot.com/#/schema/Organization/1'},
#    'inLanguage': 'en'},
#   {'@type': 'Review',
#    '@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64c4b3ab706f837cb1157928',
#    'itemReviewed': {'@id': 'https://www.trustpilot.com/#/schema/Organization/gymshark.com'},
#    'author': {'@type': 'Person',
#     'name': 'Nidhin Uthaman',
#     'url': 'https://uk.trustpilot.com/users/64c4b3aad4f64b001202b4bf/'},
#    'datePublished': '2023-07-29T08:37:31.000Z',
#    'headline': 'Fits very well and really comfortable…',
#    'reviewBody': 'Fits very well and really comfortable even during intense workouts.. love the quality of material too.',
#    'reviewRating': {'@type': 'Rating',
#     'bestRating': '5',
#     'worstRating': '1',
#     'ratingValue': '5'},
#    'publisher': {'@id': 'https://www.trustpilot.com/#/schema/Organization/1'},
#    'inLanguage': 'en'},
#   {'@type': 'Review',
#    '@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64c14156706f837cb114fc13',
#    'itemReviewed': {'@id': 'https://www.trustpilot.com/#/schema/Organization/gymshark.com'},
#    'author': {'@type': 'Person',
#     'name': 'Emma',
#     'url': 'https://uk.trustpilot.com/users/64c14155bd2ac3001227323c/'},
#    'datePublished': '2023-07-26T17:52:54.000Z',
#    'headline': 'Great outfits for workout',
#    'reviewBody': 'Well made, comfy and stylish and giving maximum durability and flex!  Certainly a stand out in any gym and for any gym style enthusiast.',
#    'reviewRating': {'@type': 'Rating',
#     'bestRating': '5',
#     'worstRating': '1',
#     'ratingValue': '5'},
#    'publisher': {'@id': 'https://www.trustpilot.com/#/schema/Organization/1'},
#    'inLanguage': 'en'},
#   {'@type': 'Review',
#    '@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64d668708939eed74a3a7e7e',
#    'itemReviewed': {'@id': 'https://www.trustpilot.com/#/schema/Organization/gymshark.com'},
#    'author': {'@type': 'Person',
#     'name': 'Steven C',
#     'url': 'https://uk.trustpilot.com/users/64d6686fd031020012517fb2/'},
#    'datePublished': '2023-08-11T18:57:20.000Z',
#    'headline': 'Fast delivery and well made',
#    'reviewBody': 'Fast delivery and well made',
#    'reviewRating': {'@type': 'Rating',
#     'bestRating': '5',
#     'worstRating': '1',
#     'ratingValue': '5'},
#    'publisher': {'@id': 'https://www.trustpilot.com/#/schema/Organization/1'},
#    'inLanguage': 'en'},
#   {'@type': 'Review',
#    '@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64ce15e2706f837cb116d650',
#    'itemReviewed': {'@id': 'https://www.trustpilot.com/#/schema/Organization/gymshark.com'},
#    'author': {'@type': 'Person',
#     'name': 'Ryan Lock',
#     'url': 'https://uk.trustpilot.com/users/64ce15e07285bd0012fd5983/'},
#    'datePublished': '2023-08-05T11:26:58.000Z',
#    'headline': 'Got sent a wrong item ordered a white t…',
#    'reviewBody': 'Got sent a wrong item ordered a white t shirt got sent a blue vest. Sent back for a return to get the t shirt. Never got the white shirt sent back to me or a refund.',
#    'reviewRating': {'@type': 'Rating',
#     'bestRating': '5',
#     'worstRating': '1',
#     'ratingValue': '1'},
#    'publisher': {'@id': 'https://www.trustpilot.com/#/schema/Organization/1'},
#    'inLanguage': 'en'},
#   {'@type': 'Review',
#    '@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64c14279706f837cb114fc47',
#    'itemReviewed': {'@id': 'https://www.trustpilot.com/#/schema/Organization/gymshark.com'},
#    'author': {'@type': 'Person',
#     'name': 'Billie-Jo Dearden',
#     'url': 'https://uk.trustpilot.com/users/5e98a83ba222f480bd6404c8/'},
#    'datePublished': '2023-07-26T17:57:45.000Z',
#    'headline': 'Quality is excellent and fantastic…',
#    'reviewBody': 'Quality is excellent and fantastic customer service. Kept up to date about the items I returned. I just reordered in a smaller size.',
#    'reviewRating': {'@type': 'Rating',
#     'bestRating': '5',
#     'worstRating': '1',
#     'ratingValue': '5'},
#    'publisher': {'@id': 'https://www.trustpilot.com/#/schema/Organization/1'},
#    'inLanguage': 'en'},
#   {'@type': 'Review',
#    '@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64c149e2706f837cb114fdcc',
#    'itemReviewed': {'@id': 'https://www.trustpilot.com/#/schema/Organization/gymshark.com'},
#    'author': {'@type': 'Person',
#     'name': 'BM',
#     'url': 'https://uk.trustpilot.com/users/64c149e1a1676b0012184f53/'},
#    'datePublished': '2023-07-26T18:29:22.000Z',
#    'headline': 'All items were too small/tight even…',
#    'reviewBody': "All items were too small/tight even though I'd measured myself exactly as you suggested",
#    'reviewRating': {'@type': 'Rating',
#     'bestRating': '5',
#     'worstRating': '1',
#     'ratingValue': '1'},
#    'publisher': {'@id': 'https://www.trustpilot.com/#/schema/Organization/1'},
#    'inLanguage': 'en'},
#   {'@type': 'Review',
#    '@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64c61cf3c4234462868dcc3a',
#    'itemReviewed': {'@id': 'https://www.trustpilot.com/#/schema/Organization/gymshark.com'},
#    'author': {'@type': 'Person',
#     'name': 'Lisa ',
#     'url': 'https://uk.trustpilot.com/users/5d7d485aab50501094634d2b/'},
#    'datePublished': '2023-07-30T10:18:59.000Z',
#    'headline': 'Great service',
#    'reviewBody': 'Great service, great product. Gym leggings fit well and are good quality. Again gym tank exactly as described and good quality. Thanks.',
#    'reviewRating': {'@type': 'Rating',
#     'bestRating': '5',
#     'worstRating': '1',
#     'ratingValue': '5'},
#    'publisher': {'@id': 'https://www.trustpilot.com/#/schema/Organization/1'},
#    'inLanguage': 'en'},
#   {'@type': 'Review',
#    '@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64bd7deb43a7bae0092a5031',
#    'itemReviewed': {'@id': 'https://www.trustpilot.com/#/schema/Organization/gymshark.com'},
#    'author': {'@type': 'Person',
#     'name': 'Gosia Grzesiak',
#     'url': 'https://uk.trustpilot.com/users/5eee6d5c63c027406314c0c2/'},
#    'datePublished': '2023-07-23T21:22:19.000Z',
#    'headline': 'Terrible',
#    'reviewBody': 'Terrible! 1st time- my parcel got “lost”  but I got charge..2nd time- completely messaged up the order at the warehouse and sent me wrong stuff…3rd time - I returned stuff worth nearly £250 and got back £23 refund …A JOKE!!!! Never again! A waste of time, and a lot of stress!Worst company ever!',
#    'reviewRating': {'@type': 'Rating',
#     'bestRating': '5',
#     'worstRating': '1',
#     'ratingValue': '1'},
#    'publisher': {'@id': 'https://www.trustpilot.com/#/schema/Organization/1'},
#    'inLanguage': 'en'},
#   {'@type': 'Review',
#    '@id': 'https://www.trustpilot.com/#/schema/Review/gymshark.com/64d1145f706f837cb1173572',
#    'itemReviewed': {'@id': 'https://www.trustpilot.com/#/schema/Organization/gymshark.com'},
#    'author': {'@type': 'Person',
#     'name': 'Linz',
#     'url': 'https://uk.trustpilot.com/users/5bf3f96c67d84465959ee4c9/'},
#    'datePublished': '2023-08-07T17:57:19.000Z',
#    'headline': 'Lovely shorts bought for my daughter',
#    'reviewBody': 'Lovely shorts bought for my daughter. She loves them as they are so comfy & look great on.',
#    'reviewRating': {'@type': 'Rating',
#     'bestRating': '5',
#     'worstRating': '1',
#     'ratingValue': '5'},
#    'publisher': {'@id': 'https://www.trustpilot.com/#/schema/Organization/1'},
#    'inLanguage': 'en'}]}

# %%
df
# Out:
#      company                      date  \
# 0   gymshark  2023-08-11T09:39:01.000Z
# 1   gymshark  2023-08-12T13:21:23.000Z
# 2   gymshark  2023-08-11T13:45:39.000Z
# 3   gymshark  2023-08-11T14:00:05.000Z
# 4   gymshark  2023-08-11T22:21:08.000Z
# ..       ...                       ...
# 95  gymshark  2023-07-26T17:57:45.000Z
# 96  gymshark  2023-07-26T18:29:22.000Z
# 97  gymshark  2023-07-30T10:18:59.000Z
# 98  gymshark  2023-07-23T21:22:19.000Z
# 99  gymshark  2023-08-07T17:57:19.000Z
#
#                                       headline  \
# 0            Efficient delivery and excellent…
# 1   Worst Customer Service Of ALL Time! Avoid.
# 2                      Gymshark are incredible
# 3     I ordered something online and received…
# 4                     Order cancelled 3 times.
# ..                                         ...
# 95         Quality is excellent and fantastic…
# 96        All items were too small/tight even…
# 97                               Great service
# 98                                    Terrible
# 99        Lovely shorts bought for my daughter
#
#                                                review               name  \
# 0   Efficient delivery and excellent customer serv...   Miss Lucy Craven
# 1   I have ordered thousands from this site and "u...              Conor
# 2   Gymshark have always given such incredible cus...         Steph Webb
# 3   I ordered something online and received someth...              Hadar
# 4   I have ordered a hoodie 3 times now as a gift ...             Nicole
# ..                                                ...                ...
# 95  Quality is excellent and fantastic customer se...  Billie-Jo Dearden
# 96  All items were too small/tight even though I'd...                 BM
# 97  Great service, great product. Gym leggings fit...              Lisa
# 98  Terrible! 1st time- my parcel got “lost”  but ...     Gosia Grzesiak
# 99  Lovely shorts bought for my daughter. She love...               Linz
#
#                                                   url ratingValue
# 0   https://uk.trustpilot.com/users/5d114d4a6d82d1...           4
# 1   https://uk.trustpilot.com/users/5d3ade847576c4...           1
# 2   https://uk.trustpilot.com/users/5cb05052499381...           5
# 3   https://uk.trustpilot.com/users/64d6229054eb0b...           1
# 4   https://uk.trustpilot.com/users/5e4854177168c0...           1
# ..                                                ...         ...
# 95  https://uk.trustpilot.com/users/5e98a83ba222f4...           5
# 96  https://uk.trustpilot.com/users/64c149e1a1676b...           1
# 97  https://uk.trustpilot.com/users/5d7d485aab5050...           5
# 98  https://uk.trustpilot.com/users/5eee6d5c63c027...           1
# 99  https://uk.trustpilot.com/users/5bf3f96c67d844...           5
#
# [100 rows x 7 columns]

# %%
df.to_csv('/Users/saho/Documents/sam/skllm/data/test_data.csv',index=False)

# %%
import requests
import concurrent.futures
import json
import pandas as pd
from bs4 import BeautifulSoup
import logging

class TrustPilotScraper:
    """
    A class for scraping reviews from Trustpilot and transforming them into a dataframe.
    """

    def __init__(self, url, num_pages):
        """
        Initialize the TrustPilotScraper object with the Trustpilot URL and number of pages to scrape.

        Args:
            url (str): The URL of the Trustpilot page to scrape.
            num_pages (int): The number of pages to scrape.
        """
        self.url = url
        self.url_company = url.split("/")[-1].split(".")[0]
        self.num_pages = num_pages

        # Configure logging
        logging.basicConfig(level=logging.INFO)
        self.logger = logging.getLogger(__name__)

    def scrape_reviews(self):
        """
        Scrape reviews from the Trustpilot URL for the specified number of pages.

        Returns:
            tuple: A tuple containing lists of reviews, headlines, ratings, and authors.
        """
        base_url = self.url + '?page='
        urls = [base_url + str(i) for i in range(1, self.num_pages + 1)]

        with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
            results = executor.map(self.__scrape_trustpilot_data, urls)

        page_results = list(results)

        reviews, headlines, ratings, authors = [], [], [], []
        for page_result in page_results:
            page_reviews, page_headlines, page_ratings, page_authors = self.__extract_nested_content(page_result)
            reviews.extend(page_reviews)
            headlines.extend(page_headlines)
            ratings.extend(page_ratings)
            authors.extend(page_authors)

        return reviews, headlines, ratings, authors

    def __scrape_trustpilot_data(self, url):
        """
        Private method to scrape data from a given Trustpilot URL.

        Args:
            url (str): The URL to scrape.

        Returns:
            dict: The scraped JSON data.
        """
        try:
            response = requests.get(url)
            response.raise_for_status()
        except requests.exceptions.RequestException as e:
            self.logger.error(f"Error scraping URL: {url}\n{str(e)}")
            return None

        try:
            soup = BeautifulSoup(response.text, 'html.parser')
            script_tag = soup.find('script', {'data-business-unit-json-ld': 'true'})
            json_str = script_tag.text.strip()
            json_data = json.loads(json_str)
            return json_data
        except (AttributeError, ValueError, KeyError) as e:
            self.logger.error(f"Error parsing JSON data for URL: {url}\n{str(e)}")
            return None

    def __get_content_from_page_results(self, page_result, key):
        """
        Private method to extract nested content from the scraped JSON data.

        Args:
            page_result (dict): The scraped JSON data for a single page.
            key (str): The key to extract from the JSON data.

        Returns:
            list: A list of extracted content.
        """
        if page_result and '@graph' in page_result:
            page_content = [i[key] for i in page_result['@graph'] if i.get('@type') == 'Review']
            return page_content
        return []

    def __extract_nested_content(self, page_result):
        """
        Private method to extract nested content from a list of scraped JSON data.

        Args:
            page_results (list): A list of scraped JSON data for multiple pages.

        Returns:
            tuple: A tuple containing lists of nested reviews, headlines, ratings, and authors.
        """
        reviews = self.__get_content_from_page_results(page_result, 'reviewBody')
        headlines = self.__get_content_from_page_results(page_result, 'headline')
        ratings = self.__get_content_from_page_results(page_result, 'reviewRating')
        authors = self.__get_content_from_page_results(page_result, 'author')
        return reviews, headlines, ratings, authors

    def transform_nested_dataframe_column(self, df, nested_col, new_cols):
        """
        Transform a nested column in the dataframe into separate columns.

        Args:
            df (pandas.DataFrame): The input dataframe.
            nested_col (str): The name of the nested column to transform.
            new_cols (list): The names of the new columns to create.

        Returns:
            pandas.DataFrame: The transformed dataframe with the new columns.
        """
        df_flat = df[nested_col].apply(pd.Series)[new_cols]
        return df_flat

    def get_dataframe_results(self, reviews, headlines, ratings, authors):
        """
        Generate a dataframe from the scraped review data.

        Args:
            reviews (list): List of review content.
            headlines (list): List of review headlines.
            ratings (list): List of review ratings.
            authors (list): List of review authors.

        Returns:
            pandas.DataFrame: The dataframe containing the review data.
        """
        df = pd.DataFrame({'review': reviews, 'author': authors, 'headline': headlines, 'ratings': ratings})
        df['company'] = self.url_company
        df_author = self.transform_nested_dataframe_column(df, 'author', ['name', 'url'])
        df_rating = self.transform_nested_dataframe_column(df, 'ratings', ['ratingValue'])
        df['company'] = self.url_company
        return pd.concat([df[['headline', 'review', 'company']], df_author, df_rating], axis=1)

    def run(self):
        """
        Run the TrustPilotScraper to scrape reviews and generate the dataframe.

        Returns:
            pandas.DataFrame: The dataframe containing the scraped review data.
        """
        reviews, headlines, ratings, authors = self.scrape_reviews()
        df = self.get_dataframe_results(reviews, headlines, ratings, authors)
        return df

# Usag
scraper = TrustPilotScraper(url='https://uk.trustpilot.com/review/gymshark.com', num_pages=10)
df = scraper.run()
print(df)
# Out:
#                                        headline  \
# 0             Efficient delivery and excellent…
# 1    Worst Customer Service Of ALL Time! Avoid.
# 2                       Gymshark are incredible
# 3      I ordered something online and received…
# 4                      Order cancelled 3 times.
# ..                                          ...
# 195                                  Best ever!
# 196                                 I hate evri
# 197                              Quick delivery
# 198                               Great product
# 199                                   Girls bag
#
#                                                 review   company  \
# 0    Efficient delivery and excellent customer serv...  gymshark
# 1    I have ordered thousands from this site and "u...  gymshark
# 2    Gymshark have always given such incredible cus...  gymshark
# 3    I ordered something online and received someth...  gymshark
# 4    I have ordered a hoodie 3 times now as a gift ...  gymshark
# ..                                                 ...       ...
# 195                                        ...........  gymshark
# 196                                   Good fit ngl ong  gymshark
# 197                                     Quick delivery  gymshark
# 198                                      Great product  gymshark
# 199                                      As advertised  gymshark
#
#                  name                                                url  \
# 0    Miss Lucy Craven  https://uk.trustpilot.com/users/5d114d4a6d82d1...
# 1               Conor  https://uk.trustpilot.com/users/5d3ade847576c4...
# 2          Steph Webb  https://uk.trustpilot.com/users/5cb05052499381...
# 3               Hadar  https://uk.trustpilot.com/users/64d6229054eb0b...
# 4              Nicole  https://uk.trustpilot.com/users/5e4854177168c0...
# ..                ...                                                ...
# 195     Aaron Hammond  https://uk.trustpilot.com/users/59d785960000ff...
# 196   Callum Chambers  https://uk.trustpilot.com/users/64c3e24eb6a350...
# 197           Haulwen  https://uk.trustpilot.com/users/56ce3d3e0000ff...
# 198      will waddell  https://uk.trustpilot.com/users/642598b1a69d19...
# 199      Peter  Birch  https://uk.trustpilot.com/users/573f213b0000ff...
#
#     ratingValue
# 0             4
# 1             1
# 2             5
# 3             1
# 4             1
# ..          ...
# 195           5
# 196           5
# 197           5
# 198           5
# 199           5
#
# [200 rows x 6 columns]

# %%
df
# Out:
#                                        headline  \
# 0             Efficient delivery and excellent…
# 1    Worst Customer Service Of ALL Time! Avoid.
# 2                       Gymshark are incredible
# 3      I ordered something online and received…
# 4                      Order cancelled 3 times.
# ..                                          ...
# 195                                  Best ever!
# 196                                 I hate evri
# 197                              Quick delivery
# 198                               Great product
# 199                                   Girls bag
#
#                                                 review   company  \
# 0    Efficient delivery and excellent customer serv...  gymshark
# 1    I have ordered thousands from this site and "u...  gymshark
# 2    Gymshark have always given such incredible cus...  gymshark
# 3    I ordered something online and received someth...  gymshark
# 4    I have ordered a hoodie 3 times now as a gift ...  gymshark
# ..                                                 ...       ...
# 195                                        ...........  gymshark
# 196                                   Good fit ngl ong  gymshark
# 197                                     Quick delivery  gymshark
# 198                                      Great product  gymshark
# 199                                      As advertised  gymshark
#
#                  name                                                url  \
# 0    Miss Lucy Craven  https://uk.trustpilot.com/users/5d114d4a6d82d1...
# 1               Conor  https://uk.trustpilot.com/users/5d3ade847576c4...
# 2          Steph Webb  https://uk.trustpilot.com/users/5cb05052499381...
# 3               Hadar  https://uk.trustpilot.com/users/64d6229054eb0b...
# 4              Nicole  https://uk.trustpilot.com/users/5e4854177168c0...
# ..                ...                                                ...
# 195     Aaron Hammond  https://uk.trustpilot.com/users/59d785960000ff...
# 196   Callum Chambers  https://uk.trustpilot.com/users/64c3e24eb6a350...
# 197           Haulwen  https://uk.trustpilot.com/users/56ce3d3e0000ff...
# 198      will waddell  https://uk.trustpilot.com/users/642598b1a69d19...
# 199      Peter  Birch  https://uk.trustpilot.com/users/573f213b0000ff...
#
#     ratingValue
# 0             4
# 1             1
# 2             5
# 3             1
# 4             1
# ..          ...
# 195           5
# 196           5
# 197           5
# 198           5
# 199           5
#
# [200 rows x 6 columns]
